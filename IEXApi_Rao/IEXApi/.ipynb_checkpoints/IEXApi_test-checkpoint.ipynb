# %%
from IEXApi import IEXApi

# %%
SYMBOL = 'AAPL'
SYMBOLS = ['GOOG', 'AAPL']
ENDPOINT = 'quote'
ENDPOINTS = ['quote', 'book']

# %%
iex = IEXApi()

# %% [markdown]
# ## Test for getting stock data

# %%
# test single symbol and single endpoint
iex.get_stock_data(symbols=SYMBOL, endpoints=ENDPOINT)
# Out:
# {'AAPL': {'quote': {'symbol': 'AAPL',
#    'companyName': 'Apple, Inc.',
#    'calculationPrice': 'close',
#    'open': 179.68,
#    'openTime': 1635985835878,
#    'close': 181.3,
#    'closeTime': 1563344127804,
#    'high': 182.1,
#    'low': 177.53,
#    'latestPrice': 179.79,
#    'latestSource': 'Close',
#    'latestTime': 'June 4, 2019',
#    'latestUpdate': 1637186124061,
#    'latestVolume': 32398202,
#    'iexRealtimePrice': 187.82,
#    'iexRealtimeSize': 105,
#    'iexLastUpdated': 1575298659304,
#    'delayedPrice': 180.57,
#    'delayedPriceTime': 1566460212005,
#    'extendedPrice': 182.4,
#    'extendedChange': 1.21,
#    'extendedChangePercent': 0.00647,
#    'extendedPriceTime': 1586460628012,
#    'previousClose': 176.8,
#    'change': 6.39,
#    'changePercent': 0.03707,
#    'iexMarketPercent': 0.0371230963664157,
#    'iexVolume': 1109914,
#    'avgTotalVolume': 32341127,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
# ...

# %%
# test single symbol and multiple endpoints
iex.get_stock_data(symbols=SYMBOL, endpoints=ENDPOINTS)
# Out:
# {'AAPL': {'quote': {'symbol': 'AAPL',
#    'companyName': 'Apple, Inc.',
#    'calculationPrice': 'close',
#    'open': 179.58,
#    'openTime': 1583617509781,
#    'close': 181.27,
#    'closeTime': 1600452031854,
#    'high': 180.64,
#    'low': 183.12,
#    'latestPrice': 182.41,
#    'latestSource': 'Close',
#    'latestTime': 'June 4, 2019',
#    'latestUpdate': 1586671923744,
#    'latestVolume': 32210200,
#    'iexRealtimePrice': 180.75,
#    'iexRealtimeSize': 100,
#    'iexLastUpdated': 1577205666457,
#    'delayedPrice': 187.24,
#    'delayedPriceTime': 1559787055681,
#    'extendedPrice': 185.7,
#    'extendedChange': 1.2,
#    'extendedChangePercent': 0.00671,
#    'extendedPriceTime': 1578643097124,
#    'previousClose': 175.4,
#    'change': 6.41,
#    'changePercent': 0.03764,
#    'iexMarketPercent': 0.0357447060671486,
#    'iexVolume': 1098269,
#    'avgTotalVolume': 32384681,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
#    'iexAskSize': 0,
# ...

# %%
# test multiple symbols and single endpoint
iex.get_stock_data(symbols=SYMBOLS, endpoints=ENDPOINT)
# Out:
# {'GOOG': {'quote': {'symbol': 'GOOG',
#    'companyName': 'Alphabet, Inc.',
#    'calculationPrice': 'close',
#    'open': 1059.4,
#    'openTime': 1611587979258,
#    'close': 1059.26,
#    'closeTime': 1611290227597,
#    'high': 1058.91,
#    'low': 1083.94,
#    'latestPrice': 1101.58,
#    'latestSource': 'Close',
#    'latestTime': 'June 4, 2019',
#    'latestUpdate': 1570715408594,
#    'latestVolume': 2861894,
#    'iexRealtimePrice': 1086.1,
#    'iexRealtimeSize': 105,
#    'iexLastUpdated': 1567540578448,
#    'delayedPrice': 1066.59,
#    'delayedPriceTime': 1618333436965,
#    'extendedPrice': 1103.64,
#    'extendedChange': 1.93,
#    'extendedChangePercent': 0.00186,
#    'extendedPriceTime': 1612034325967,
#    'previousClose': 1039.1,
#    'change': 17.17,
#    'changePercent': 0.01669,
#    'iexMarketPercent': 0.0648581483842955,
#    'iexVolume': 180223,
#    'avgTotalVolume': 1784555,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
# ...

# %%
# test multiple symbols and multiple endpoints
iex.get_stock_data(symbols=SYMBOLS, endpoints=ENDPOINTS)
# Out:
# {'GOOG': {'quote': {'symbol': 'GOOG',
#    'companyName': 'Alphabet, Inc.',
#    'calculationPrice': 'close',
#    'open': 1069.9,
#    'openTime': 1610071304566,
#    'close': 1096.17,
#    'closeTime': 1587362862704,
#    'high': 1077.65,
#    'low': 1052.95,
#    'latestPrice': 1076.24,
#    'latestSource': 'Close',
#    'latestTime': 'June 4, 2019',
#    'latestUpdate': 1592176642390,
#    'latestVolume': 2890362,
#    'iexRealtimePrice': 1066.6,
#    'iexRealtimeSize': 102,
#    'iexLastUpdated': 1587923235845,
#    'delayedPrice': 1056.3,
#    'delayedPriceTime': 1614205122105,
#    'extendedPrice': 1086.91,
#    'extendedChange': 1.91,
#    'extendedChangePercent': 0.0018,
#    'extendedPriceTime': 1591953459477,
#    'previousClose': 1046.49,
#    'change': 17.58,
#    'changePercent': 0.01632,
#    'iexMarketPercent': 0.06538594481758112,
#    'iexVolume': 180147,
#    'avgTotalVolume': 1822710,
#    'iexBidPrice': 0,
#    'iexBidSize': 0,
#    'iexAskPrice': 0,
# ...

# %% [markdown]
# ## Test for getting investors exchange data

# %%
iex.get_exchange_data(endpoint='tops', symbols=SYMBOLS)
# Out:
# [{'symbol': 'GOOG',
#   'sector': 'letcrngehsoecovisy',
#   'securityType': 'sc',
#   'bidPrice': 0,
#   'bidSize': 0,
#   'askPrice': 0,
#   'askSize': 0,
#   'lastUpdated': 1581722778249,
#   'lastSalePrice': 1099.3,
#   'lastSaleSize': 102,
#   'lastSaleTime': 1617783838243,
#   'volume': 184446},
#  {'symbol': 'AAPL',
#   'sector': 'conothnycllcegeetior',
#   'securityType': 'cs',
#   'bidPrice': 0,
#   'bidSize': 0,
#   'askPrice': 0,
#   'askSize': 0,
#   'lastUpdated': 1604708905194,
#   'lastSalePrice': 181.46,
#   'lastSaleSize': 104,
#   'lastSaleTime': 1587363600902,
#   'volume': 1132426}]
